# %%
import pandas as pd

df1 = pd.read_excel(r'C:\Users\ierrazuriz\Desktop\RV Screen USD Corporates.xlsx', sheet_name='DataBaseUSD All')
df2 = pd.read_excel(r'C:\Users\ierrazuriz\Desktop\CREDIT LATAM.xlsm', sheet_name='SUMMARY')
df1.drop(df2.iloc[:, 90:], inplace = True, axis = 1)
df2.drop(df2.iloc[:, 25:], inplace = True, axis = 1)
df2
# Out:
#                Unnamed: 1          Unnamed: 2              Unnamed: 3  \
# 0    NaN              NaN                 NaN                     NaN
# 1    NaN          Company             Country                  Sector
# 2    NaN           AA2000           Argentina             Industrials
# 3    NaN    AES ARGENTINA           Argentina               Utilities
# 4    NaN        ADECOAGRO           Argentina        Consumer Staples
# 5    NaN         ALBANESI           Argentina               Utilities
# 6    NaN            ARCOR           Argentina        Consumer Staples
# 7    NaN            ARCOS           Argentina  Consumer Discretionary
# 8    NaN             AYSA           Argentina               Utilities
# 9    NaN      CABLEVISION           Argentina  Communication Services
# 10   NaN           CAPXAR           Argentina               Utilities
# 11   NaN              CGC           Argentina                  Energy
# ...
